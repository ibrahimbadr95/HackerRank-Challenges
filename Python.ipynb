# %% [markdown]
# ## 1. Say "Hello, World!" With Python
# Here is a sample line of code that can be executed in Python:
#
# print("Hello, World!")
#
# You can just as easily store a string as a variable and then print it to stdout:
#
# my_string = "Hello, World!"
# print(my_string)
#
# The above code will print Hello, World! on your screen. Try it yourself in the editor below!
#
# Input Format
#
# You do not need to read any input in this challenge.
#
# Output Format
#
# Print Hello, World! to stdout.
#
# Sample Output 0
#
# Hello, World!

# %%
print("Hello, World!")

# %% [markdown]
# ## 2. Python If-Else
# ![image.png](attachment:image.png)

# %%
import math
import os
import random
import re
import sys


if __name__ == '__main__':
    n = int(input().strip())
    if n % 2 == 1:
        print("Weird")
    elif (n % 2 == 0) and n >=2 and n <= 5:
        print("Not Weird")
    elif (n % 2 == 0) and n >=6 and n <= 20:
        print("Weird")
    elif (n % 2 == 0) and n > 20:
        print("Not Weird")
# Out:
# Weird

# %% [markdown]
# ## 3. Arithmetic Operators
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a + b)
    print(a - b)
    print(a * b)
# Out:
# 3
# -1
# 2

# %% [markdown]
# ## 4. Python: Division
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a // b)
    print(a / b)

# %% [markdown]
# ## 5. Loops
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(n):
        print(i * i)
# Out:
# 0
# 1

# %% [markdown]
# ## 6. Write a function
# ![image.png](attachment:image.png)

# %%
def is_leap(year):
    leap = False    
    if year % 4 == 0 and year % 100 != 0:
        leap = True
    elif year % 100 == 0 and year % 400 == 0:
        leap = True
    return leap

year = int(input())
print(is_leap(year))

# %% [markdown]
# ## 7. Print Function
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    n = int(input())
    result = ""
    for i in range(n):
        result += str(i + 1)
            
    print(result)

# %% [markdown]
# ## 8. List Comprehensions
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    
    result = [[a, b, c] for a in range(x+1) for b in range(y+1) for c in range(z+1) if a+b+c != n]
    print(result)

# %% [markdown]
# ## 9. Find the Runner-Up Score!
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    arr_list = list(set(arr))
    arr_list.sort()
    print(arr_list[-2])

# %% [markdown]
# ## 10. sWAP cASE
# ![image.png](attachment:image.png)

# %%
def swap_case(s):
    result = ""
    for l in s:
        if l.isupper():
            l = l.lower()
        else:
            l = l.upper()
        result += l
    return result

if __name__ == '__main__':
    s = input()
    result = swap_case(s)
    print(result)

# %% [markdown]
# ## 11. Nested Lists
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    record = []
    for _ in range(int(input())):
        name = input()
        score = float(input())
        record.append([name, score])

    scores = set()
    for s in record:
        scores.add(s[1])

    sorted_scores = sorted(scores)

    result = []
    for stu in record:
        if stu[1] == sorted_scores[1]:
            result.append(stu[0])
            # print(stu)
    result.sort()

    for i in result:
        print(i)

# %% [markdown]
# ## 12. Finding the percentage
# ![image.png](attachment:image.png)

# %%
def get_average_mark(student_marks, query_name):
    marks = student_marks[query_name]
    return sum(marks) / len(marks)

if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
        
    query_name = input()
    
    avg = get_average_mark(student_marks, query_name)
    
    print(f"{avg:.2f}")

# %% [markdown]
# ## 13. itertools.product()
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
from itertools import product

a = input().split()
b = input().split()

a_list = list(map(int, a))
b_list = list(map(int, b))

prod = list(product(a_list, b_list))

print(*prod)

# %% [markdown]
# ## 14. itertools.permutations()
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
from itertools import permutations

inp = input().split()
sort = ''.join(sorted(inp[0], key=lambda x: (x.isdigit(), x)))

pre_list = list(permutations(sort, int(inp[1])))

for i in range(len(pre_list)):
    print(''.join(pre_list[i]))

# %% [markdown]
# ## 15. Polar Coordinates
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
import cmath

z = complex(input())
r = abs(z)
cita = cmath.phase(z)

print(r)
print(cita)

# %% [markdown]
# ## 16. Introduction to Sets
# ![image.png](attachment:image.png)

# %%
def average(array):
    input_set = set(array)
    return sum(input_set) / len(input_set)

if __name__ == '__main__':
    n = int(input())
    arr = list(map(int, input().split()))
    result = average(arr)
    print(result)

# %% [markdown]
# ## 17 Find Angle MBC
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
import math

ab = int(input())
bc = int(input())

angle = math.atan(ab / bc)

print(str(round(math.degrees(angle))) + chr(176))

# %% [markdown]
# ## 18 Symmetric Difference
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

m = int(input())
m_input = input().split()
m_list = list(map(int, m_input))
m_set = set(m_list)

n = int(input())
n_input = input().split()
n_list = list(map(int, n_input))
n_set = set(n_list)

un = m_set.union(n_set)

in_set = m_set.intersection(n_set)
result = []
for i in un:
    if i not in in_set:
        result.append(i)

result.sort()

for i in result:
    print(i)

# %% [markdown]
# ## 19 Validating UID
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

def is_repeated(id_num):
    if (len(set(id_num)) == len(id_num)):
        return False
    else:
        return True

t_num = int(input())

id_list = []
result = []
for i in range(t_num):
    id_list.append(str(input()))
for id_num in id_list:
    upper_case_count = sum(1 for l in id_num if l.isupper())
    digit_count = sum(1 for l in id_num if l.isdigit())
    alphanum_count = sum(1 for l in id_num if l.isalnum())
    has_repeated = is_repeated(id_num)
    
    if upper_case_count >= 2 and digit_count >= 3 and alphanum_count == len(id_num) and has_repeated == False and len(id_num) == 10:
        result.append("Valid")
    else:
        result.append("Invalid")
        
for i in result:
    print(i)
