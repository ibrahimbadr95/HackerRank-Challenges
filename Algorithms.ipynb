# %% [markdown]
# ## 1. Solve Me First
# ![image.png](attachment:image.png)

# %%
def solveMeFirst(a,b):
    return a + b

num1 = int(input())
num2 = int(input())
res = solveMeFirst(num1,num2)
print(res)
# Out:
# 3

# %% [markdown]
# ## 2. Compare the Triplets
# ![image.png](attachment:image.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'compareTriplets' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER_ARRAY a
#  2. INTEGER_ARRAY b
#

def compareTriplets(a, b):
    result = [0, 0]
    for (a_el, b_el) in zip(a, b):
        if a_el > b_el:
            result = [result[0] + 1, result[1]]
        elif b_el > a_el:
            result = [result[0], result[1] + 1]
        else:
            result = result

    return result

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    a = list(map(int, input().rstrip().split()))

    b = list(map(int, input().rstrip().split()))

    result = compareTriplets(a, b)

    fptr.write(' '.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %% [markdown]
# ## 3. Diagonal Difference
# ![image.png](attachment:image.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'diagonalDifference' function below.
#
# The function is expected to return an INTEGER.
# The function accepts 2D_INTEGER_ARRAY arr as parameter.
#

def diagonalDifference(arr):
    main_d = []
    sec_d = []
    for i in range(len(arr)):
        for j in range(len(arr)):
            if i == j: 
                main_d.append(arr[i][j])

    for i in range(len(arr)):
        for j in range(len(arr)):
            if j == (len(arr) - i -1):
                sec_d.append(arr[i][j])
    return abs(sum(main_d) - sum(sec_d))


if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))

    result = diagonalDifference(arr)

    fptr.write(str(result) + '\n')

    fptr.close()

# %% [markdown]
# ## 4. Plus Minus
# ![image.png](attachment:image.png)

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'plusMinus' function below.
#
# The function accepts INTEGER_ARRAY arr as parameter.
#

def plusMinus(arr):
    num_pos = 0
    num_neg = 0
    num_zero = 0
    
    for elm in arr:
        if elm > 0:
            num_pos = num_pos +1
        elif elm < 0:
            num_neg= num_neg +1
        else:
            num_zero = num_zero +1
    p_pos = "{:.6}".format(num_pos/ len(arr))
    p_neg = "{:.6}".format(num_neg/ len(arr))
    p_zero = "{:.6}".format(num_zero/ len(arr))
    
    print(p_pos)
    print(p_neg)
    print(p_zero)

if __name__ == '__main__':
    n = int(input().strip())
    arr = list(map(int, input().rstrip().split()))

    plusMinus(arr)

# %% [markdown]
# ## 5. Mini-Max Sum
# ![image.png](attachment:image.png)

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'miniMaxSum' function below.
#
# The function accepts INTEGER_ARRAY arr as parameter.
#

def miniMaxSum(arr):
    min = arr[0]
    max = arr[0]
    
    for elm in arr:
        if elm > max:
            max = elm
    
    for elm in arr:
        if elm < min:
            min = elm
    print(f"{sum(arr) - max} {sum(arr) - min}")

if __name__ == '__main__':

    arr = list(map(int, input().rstrip().split()))

    miniMaxSum(arr)

# %% [markdown]
# ## 6. Time Conversion
# ![image.png](attachment:image.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'timeConversion' function below.
#
# The function is expected to return a STRING.
# The function accepts STRING s as parameter.
#
def timeConversion(s):
    tokens = s.split(':')
    time = tokens[2][2]
    sec = re.match(r'(\d+)([A-Za-z]+)', tokens[2])
    result = []
     
    if time == 'P':
        if (int(tokens[0]) == 12):
            hour = str(int(tokens[0]))
        else:
            hour = str(int(tokens[0]) + 12)
        result.append(hour)
        result.append(tokens[1])
        result.append(sec.group(1))
    elif time == 'A' and tokens[0] == "12":
        result.append(str(int(tokens[0]) - 12)+ '0')
        result.append(tokens[1])
        result.append(sec.group(1))
 
    else:
        result.append(tokens[0])
        result.append(tokens[1])
        result.append(sec.group(1))
                 
    return ':'.join(result)

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = timeConversion(s)

    fptr.write(result + '\n')

    fptr.close()
